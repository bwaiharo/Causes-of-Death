# %%
import pandas as pd

# %%
NY_data_df = pd.read_csv("NY_death_data.txt",  delim_whitespace=True)
NY_data_df.tail()
# Out:
#                                                   Notes UCD - ICD Chapter  \
# 8735  estimates. Population figures for Infant Age G...               NaN
# 8736  figures for years 2001 - 2009 differ slightly ...               NaN
# 8737             were available at the time of release.               NaN
# 8738  7. The population figures used in the calculat...               NaN
# 8739  resident population that is under one year of ...               NaN
#
#      UCD - ICD Chapter Code Race Race Code Gender Gender Code  \
# 8735                    NaN  NaN       NaN    NaN         NaN
# 8736                    NaN  NaN       NaN    NaN         NaN
# 8737                    NaN  NaN       NaN    NaN         NaN
# 8738                    NaN  NaN       NaN    NaN         NaN
# 8739                    NaN  NaN       NaN    NaN         NaN
#
#      Ten-Year Age Groups  Ten-Year Age Groups Code  Year  Year Code Deaths  \
# ...

# %%
cleanNYDatadf = NY_data_df.dropna()
cleanNYDatadfhead
